# %% [markdown]
# **ACTIVIDAD 1**
# ALUMNO: LUIS ANGEL TOHALINO FARFAN
# CURSO : QUÍMICA GENERAL

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# !pip install drawdata
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.9/121.9 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.5/93.5 kB 10.1 MB/s eta 0:00:00
# ...

# %%
from drawdata import draw_histogram, draw_scatter

# %%
draw_histogram()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/histogram.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#         x      y  z
# 0   0.000  0.094  a
# 1   0.025  0.164  a
# 2   0.050  0.392  a
# 3   0.075  0.598  a
# 4   0.100  0.706  a
# 5   0.125  0.798  a
# 6   0.150  0.836  a
# 7   0.175  0.960  a
# 8   0.200  0.920  a
# 9   0.225  0.880  a
# 10  0.250  0.822  a
# 11  0.275  0.788  a
# 12  0.300  0.760  a
# 13  0.325  0.724  a
# 14  0.350  0.692  a
# 15  0.375  0.662  a
# 16  0.400  0.624  a
# 17  0.425  0.590  a
# 18  0.450  0.542  a
# 19  0.475  0.510  a
# 20  0.500  0.476  a
# 21  0.525  0.454  a
# 22  0.550  0.430  a
# 23  0.575  0.410  a
# 24  0.600  0.392  a
# 25  0.625  0.378  a
# 26  0.650  0.372  a
# 27  0.675  0.366  a
# 28  0.700  0.358  a
# 29  0.725  0.354  a
# 30  0.750  0.350  a
# 31  0.775  0.346  a
# 32  0.800  0.346  a
# 33  0.825  0.346  a
# 34  0.850  0.348  a
# 35  0.875  0.348  a
# 36  0.900  0.352  a
# 37  0.925  0.352  a
# 38  0.950  0.352  a
# 39  0.975  0.358  a

# %% [markdown]
# Gráfico 1:![grafico 1.png](data:image/png;base64,...)

# %%
draw_scatter()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/scatter.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
df = pd.read_csv("N2-100K.csv")

# %%
df
# Out:
#               x          y  z
# 0    -12.847469  -9.406963  a
# 1      0.213488  58.581699  a
# 2    -24.340064  -0.786958  a
# 3      5.022507  25.670553  a
# 4     -8.739731  12.920301  a
# ..          ...        ... ..
# 331  365.254116  -1.381777  a
# 332  417.908624  26.794938  a
# 333  425.267778   2.063429  a
# 334  415.421486  -5.787666  a
# 335  410.331948  10.235585  a
#
# [336 rows x 3 columns]

# %%
plt.scatter(df["x"],df["y"])

# %%
df1 = pd.read_csv("N2-300K.csv")

# %%
df1
# Out:
#               x          y  z
# 0      6.655913 -19.447068  a
# 1     35.706873 -10.922870  a
# 2     24.073354  16.639819  a
# 3      9.699439 -17.275054  a
# 4     15.220317   6.383997  a
# ..          ...        ... ..
# 314  533.181844   9.526864  a
# 315  563.055741   3.045503  a
# 316  517.544776  36.381832  a
# 317  568.026277 -11.819091  a
# 318  581.938159  18.153650  a
#
# [319 rows x 3 columns]

# %%
plt.scatter(df1["x"],df1["y"])

# %%
df2 = pd.read_csv("N2-700K.csv")

# %%
df2
# Out:
#               x          y  z
# 0    -17.746445  12.101477  a
# 1     26.832845   3.888312  a
# 2    -29.487744   9.610806  a
# 3     64.684795  40.348703  a
# 4      9.342535  11.810335  a
# ..          ...        ... ..
# 249  697.502734  88.892168  a
# 250  665.809972  45.077031  a
# 251  715.479919  13.541011  a
# 252  698.331318  82.200934  a
# 253  745.318731  37.424128  a
#
# [254 rows x 3 columns]

# %%
plt.scatter(df2["x"],df2["y"])

# %% [markdown]
# Extraemos las medidas de tendencia central de cada una de las tablas del N2 a distintas temperaturas.

# %%
df.describe()
# Out:
#                 x           y
# count  336.000000  336.000000
# mean   169.444734  209.457778
# std    114.090957  134.650403
# min    -39.674235  -13.930667
# 25%     69.441073   85.266108
# 50%    162.225837  199.393934
# 75%    254.082189  331.543333
# max    427.089587  469.322273

# %%
df1.describe()
# Out:
#                 x           y
# count  319.000000  319.000000
# mean   232.500368  158.536815
# std    152.064950   91.448523
# min    -21.346876  -37.240825
# 25%    111.798165   83.552285
# 50%    203.917369  175.046981
# 75%    324.881042  241.786175
# max    581.938159  340.225880

# %%
df2.describe()
# Out:
#                 x           y
# count  254.000000  254.000000
# mean   393.157546  130.596788
# std    183.036762   58.496749
# min    -29.487744   -5.429154
# 25%    240.405077   85.847765
# 50%    401.259463  130.226870
# 75%    534.890068  176.322852
# max    745.318731  255.504444

# %%
draw_histogram()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/histogram.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
dfh = pd.read_csv("Histograma1.csv")

# %%
dfh
# Out:
#          x      y  z
# 0    0.000  0.162  a
# 1    0.025  0.252  a
# 2    0.050  0.402  a
# 3    0.075  0.644  a
# 4    0.100  0.920  a
# ..     ...    ... ..
# 115  0.875  0.090  c
# 116  0.900  0.060  c
# 117  0.925  0.036  c
# 118  0.950  0.012  c
# 119  0.975  0.012  c
#
# [120 rows x 3 columns]

# %%
plt.scatter(dfh["x"],dfh["y"])

# %%
dfh.describe()
# Out:
#                 x           y
# count  120.000000  120.000000
# mean     0.487500    0.213750
# std      0.289795    0.236876
# min      0.000000    0.000000
# 25%      0.243750    0.012000
# 50%      0.487500    0.146000
# 75%      0.731250    0.335500
# max      0.975000    0.972000

# %% [markdown]
# Gráfico en draw_histogram: ![histo1.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Gráfico 2 con gases diferentes a temperatura constante:![grafico 1.png](data:image/png;base64,...)

# %%
draw_scatter()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/scatter.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
df3 = pd.read_csv("Cl2-300K.csv")

# %%
df3
# Out:
#               x          y  z
# 0      8.750739 -53.555925  a
# 1      6.119577  21.904968  a
# 2      2.137263  18.576386  a
# 3    -13.158980  -4.771785  a
# 4     18.235875  32.154626  a
# ..          ...        ... ..
# 313  448.108373  40.635534  a
# 314  400.619857  28.535971  a
# 315  396.268132  36.547943  a
# 316  441.965199  40.853687  a
# 317  448.085288  87.565517  a
#
# [318 rows x 3 columns]

# %%
plt.scatter(df3["x"],df3["y"])

# %%
df3.describe()
# Out:
#                 x           y
# count  318.000000  318.000000
# mean   165.062777  242.761400
# std    117.370984  158.254059
# min    -16.318365  -53.555925
# 25%     69.028213   88.059820
# 50%    151.638270  234.964770
# 75%    246.551671  391.023265
# max    448.108373  538.835112

# %%
plt.scatter(df1["x"],df1["y"])

# %%
df1.describe()
# Out:
#                 x           y
# count  319.000000  319.000000
# mean   232.500368  158.536815
# std    152.064950   91.448523
# min    -21.346876  -37.240825
# 25%    111.798165   83.552285
# 50%    203.917369  175.046981
# 75%    324.881042  241.786175
# max    581.938159  340.225880

# %%
df4 = pd.read_csv("He-300K.csv")

# %%
df4
# Out:
#               x          y  z
# 0     -1.255666  12.979755  a
# 1     10.667748 -14.763875  a
# 2    -41.321050  16.854820  a
# 3    -27.919120  50.292822  a
# 4     21.307906  55.491059  a
# ..          ...        ... ..
# 262  704.009168  72.640656  a
# 263  723.495858  83.727040  a
# 264  700.946455  25.966800  a
# 265  659.657022  83.395677  a
# 266  690.992080  99.378001  a
#
# [267 rows x 3 columns]

# %%
plt.scatter(df4["x"],df4["y"])

# %%
draw_histogram()
# Out:
#         <iframe
#             width="800"
#             height="550"
#             src="https://drawdata.xyz/histogram.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
dfh1 = pd.read_csv("Histograma2.csv")

# %%
dfh1
# Out:
#          x      y  z
# 0    0.000  0.112  a
# 1    0.025  0.326  a
# 2    0.050  0.576  a
# 3    0.075  0.768  a
# 4    0.100  0.880  a
# ..     ...    ... ..
# 115  0.875  0.046  c
# 116  0.900  0.030  c
# 117  0.925  0.008  c
# 118  0.950  0.008  c
# 119  0.975  0.000  c
#
# [120 rows x 3 columns]

# %%
plt.scatter(dfh1["x"],dfh1["y"])

# %%
dfh1.describe()
# Out:
#                 x           y
# count  120.000000  120.000000
# mean     0.487500    0.156483
# std      0.289795    0.206854
# min      0.000000   -0.006000
# 25%      0.243750    0.000000
# 50%      0.487500    0.066000
# 75%      0.731250    0.256000
# max      0.975000    0.880000

# %% [markdown]
# Gráfico 2 en draw_histogram:![histo2.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# **RESPUESTA A LA ACTIVIDAD:**
# Al analizar la gráfica de número de moléculas versus velocidad molecular a temperatura constante, estas medidas de tendencia central proporcionan información sobre la velocidad promedio del gas. Esto puede ser útil para comprender cómo las moléculas se comportan a nivel molecular y cómo la temperatura constante afecta a la distribución de velocidades. Si la media y la mediana son similares, podría indicar una distribución simétrica de velocidades.
#
# REFERENCIAS:
# * Chang, R. (2015). Química (12ª edición). McGraw-Hill.
#
# ![chang.jpg](data:image/jpeg;base64,...)
