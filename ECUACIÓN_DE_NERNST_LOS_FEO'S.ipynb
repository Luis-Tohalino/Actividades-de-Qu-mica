# %% [markdown]
# #ECUACIÓN DE NERNST
# By: Los FeO's

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# EMPEZAMOS CON EL CÓDIGO (ESTA CALCULADORA SE USARÁ PARA DEMOSTRAR LA ECUACIÓN DE NERNST APLICADO EN LA PILA DE DANIEL, ASIMISMO, SERVIRÁ PARA REALIZAR OTRAS OPERACIONES CON DIFERENTES ÁNODOS, CÁTODOS, CONCENTRACIONES, ETC., QUE INVOLUCREN LA ECUACIÓN DE NERNST).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#DEFINIMOS LA FÓRMULA DE NERNST QUE EMPLEAREMOS

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#EXTRAEREMOS UNA TABLA CON LOS POTENCIALES DE REDUCCIÓN

# %%
url = "https://es.wikipedia.org/wiki/Anexo:Tabla_de_potenciales_de_reducci%C3%B3n"
tabla = pd.read_html(url)

# %%
tabla[0]
# Out:
#             Media reacción Media reacción.1 Media reacción.2 Eo (V)
# 0             Li+(aq) + e−                →            Li(s)  −3.05
# 1             Rb+(aq) + e−                →            Rb(s)  −2.98
# 2              K+(aq) + e−                →             K(s)  −2.93
# 3             Cs+(aq) + e−                →            Cs(s)  −2.92
# 4           Ba2+(aq) + 2e−                →            Ba(s)  −2.91
# ..                     ...              ...              ...    ...
# 140          Ag2+(aq) + e−                →          Ag+(aq)  +1.98
# 141           S2O82- + 2e–                →           2SO42-  +2.07
# 142  HMnO4(aq) + 3H+ + 2e−                →   MnO2(s) + 2H2O  +2.09
# 143            F2(g) + 2e−                →          2F−(aq)  +2.87
# 144      F2(g) + 2H+ + 2e−                →          2HF(aq)  +3.05
#
# [145 rows x 4 columns]

# %%
#PARA ESTE PROBLEMA, USAREMOS EL NÚMERO 23 PARA EL ÁNODO Y 74 PARA EL CÁTODO

# %%
A = int(input("Busque el ánodo que desea extraer de la tabla: "))
A1 = tabla[0].iloc[i1,3]
print(A1,"\n")

C = int(input("Busque el cátodo que desea extraer de la tabla: "))
C2 = tabla[0].iloc[i2,3]
print(C2)
# Out:
# Busque el ánodo que desea extraer de la tabla: 23
# −0.76
#
# Busque el cátodo que desea extraer de la tabla: 74
# +0.34

# %%
E1 = float(input("Ingrese valor del potencial del ánodo: "))

E2 = float(input("Ingrese valor del potencial del cátodo: "))

ET = E2 - E1
print("El potencial estándar es: ", ET, "V")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ***ADVERTENCIA***
#
# En reacciones heterogéneas, debido a que las concentraciones de sólidos y líquidos puros permanecen invariables estas no intervienen en el cálculo de la constante.
#
# En otras palabras, si es sólido o líquido puro la concentración será igual a 1.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
concentracion_aA = float(input("Inserte la concentración de [A]: "))
coeficiente_aA = int(input("Inserte el coeficiente de a: "))

concentracion_bB = float(input("\nInserte la concentración de [B]: "))
coeficiente_bB = int(input("Inserte el coeficiente de b: "))

concentracion_cC = float(input("\nInserte la concentración de [C]: "))
coeficiente_cC = int(input("Inserte el coeficiente de c: "))

concentracion_dD = float(input("\nInserte la concentración de [D]: "))
coeficiente_dD = int(input("Inserte el coeficiente de d: "))

# Calculando el cociente de reacción (Q)

Q = (concentracion_cC**coeficiente_cC * concentracion_dD**coeficiente_dD) / (concentracion_aA**coeficiente_aA * concentracion_bB**coeficiente_bB)

print("\nEl valor del Q es: ",Q)
# Out:
# Inserte la concentración de [A]: 1
# Inserte el coeficiente de a: 1
#
# Inserte la concentración de [B]: 0.25
# Inserte el coeficiente de b: 1
#
# Inserte la concentración de [C]: 1
# Inserte el coeficiente de c: 1
#
# Inserte la concentración de [D]: 0.5
# Inserte el coeficiente de d: 1
#
# El valor del Q es:  2.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n = int(input("Ingrese el número de electrones que se necesitará para balancear la reacción: "))

E = ET - (0.05916 / (n)) * math.log(Q,10)

print("\nEl resultado de la ecuación de Nernst es: ",E,"V")
# Out:
# Ingrese el número de electrones que se necesitará para balancear la reacción: 2
#
# El resultado de la ecuación de Nernst es:  1.0910955327282594 V

# %% [markdown]
# Integrantes de los FeO's que trabajaron y se amanecieron sin usar ChatGPT:
#
# * Lopez Escobar, Angelo Stephano
#
# * Medina Dávila, Gabriela de Fátima
#
# * Tohalino Farfan, Luis Angel
#
#
#
#
#
#
#
#
# Referencias:
#
# Chang, R. (2015). Química (12ª edición). McGraw-Hill.
#
# ![chang.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **GIT-HUB DONDE SE ENCUENTRA EL TRABAJO DEL GRUPO:**
#
# https://github.com/Luis-Tohalino/Actividades-de-Qu-mica
